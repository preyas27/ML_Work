# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f57cf13-474a-425b-ba69-618beadd7d15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f57cf13-474a-425b-ba69-618beadd7d15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import math

# %%
data = pd.read_csv(io.BytesIO(uploaded['BuyComputer.csv']))
data.drop(columns=['User ID',],axis=1,inplace=True)

# %%
X = data.iloc[:,:-1].values
X

# %%
Y = data.iloc[:,-1:]
Y

# %%
data_train, data_test, target_train, target_test = train_test_split(X,Y, test_size = 0.30, random_state = 5)

# %%
scaler = preprocessing.MinMaxScaler()
data_test = scaler.fit_transform(data_test)
data_train = scaler.fit_transform(data_train)
target_train = scaler.fit_transform(target_train)
target_test = scaler.fit_transform(target_test)

# %%
data_train

# %%
y_pred = []
len_x = len(data_train[0])
w = []
b = 0.2
print(len_x)

# %%
entries = len(data_train[:,0])
entries

# %%
for weights in range(len_x):
  w.append(0)
w

# %%
e = math.e
def sigmoid(z):
  return (1/(1+e^(-1)*z))

# %%
def predict(inputs):
  return (w[0]*inputs[0] + w[1]*inputs[1])

# %%
def loss_func(y,a):
  J = (-1)*y*math.log(sigmoid(a)) + (y-1)*math.log(sigmoid(1- a))
  return J

# %%
predict(data_train[0])

# %%
dw = []
db = 0
J=0
J
alpha = 0.1
for x in range(len_x):
  dw.append(0)
w = dw

# %%
LR = LogisticRegression(random_state = 0)
model = LR.fit(data_train, target_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y = model.predict(data_test)
y

# %%
score = accuracy_score(y, target_test)
score

# %%
cm = confusion_matrix(y, target_test)
